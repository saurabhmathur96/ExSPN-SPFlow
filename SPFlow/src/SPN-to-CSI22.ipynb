# %%
import numpy as np
import pandas as pd

frame = pd.read_excel("data_gdm_discrete_BMI_merged.xlsx", engine="openpyxl")
frame.oDM = (frame.oDM == 2).astype(int)
for name in frame.columns:
    frame[name] = frame[name].astype('category')

print (frame)
print (frame.oDM.value_counts())
# Out:
#      AgeCat BMICat Race Education GravCat SmokeCat1 SmokeCat2 oDM
# 0         3      0    1         3       2         1         1   0
# 1         1      2    2         2       1         1         2   0
# 2         0      0    2         1       1         2         2   0
# 3         2      2    3         3       2         2         2   0
# 4         1      0    3         4       1         2         2   0
# ...     ...    ...  ...       ...     ...       ...       ...  ..
# 9215      2      1    1         4       2         1         1   0
# 9216      1      0    3         3       2         2         2   0
# 9217      0      0    3         1       2         2         2   0
# 9218      2      1    1         2       3         1         1   0
# 9219      3      2    1         5       1         1         1   0
#
# [9220 rows x 8 columns]
# 0    8832
# 1     388
# Name: oDM, dtype: int64

# %%
frame.Race.value_counts()
# Out:
# 1    5626
# 3    1501
# 2    1255
# 8     375
# 5     372
# 7      52
# 6      33
# 4       6
# Name: Race, dtype: int64

# %%
from imblearn.under_sampling import NearMiss

ros = NearMiss(version = 2)
X_res, y_res = ros.fit_resample(frame.drop('oDM', axis=1), frame.oDM)
X_res['oDM'] = y_res
frame = X_res

print (frame)
# Out:
#     AgeCat BMICat Race Education GravCat SmokeCat1 SmokeCat2 oDM
# 0        2      2    4         4       1         2         2   0
# 1        3      2    4         3       1         1         1   0
# 2        2      0    4         3       1         2         2   0
# 3        2      0    5         4       2         2         2   0
# 4        2      0    5         4       1         1         2   0
# ..     ...    ...  ...       ...     ...       ...       ...  ..
# 771      1      1    1         4       1         2         2   1
# 772      3      2    1         3       2         1         2   1
# 773      2      2    1         5       1         1         2   1
# 774      4      2    1         3       1         1         2   1
# 775      2      2    3         4       1         2         2   1
#
# [776 rows x 8 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from spn.algorithms.LearningWrappers import learn_parametric
from spn.structure.leaves.parametric.Parametric import Categorical, Gaussian
from spn.structure.Base import Context
import warnings 

train_data = frame.to_numpy()
names = frame.columns.tolist()
categories = ['Race', 'oDM']
ptypes = [Categorical if n in categories else Gaussian for n in names]
categorical = [n in categories for n in names]

# %%
from spn.algorithms.Inference import log_likelihood

for n in [20, 40, 60, 80, 100]:
    splitter = StratifiedKFold()
    ll = []
    for train_i, test_i in splitter.split(train_data, train_data[:, -1]):
        train = train_data[train_i]
        test = train_data[test_i]
        
        
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            context = Context(parametric_types = ptypes).add_domains(train)
            net = learn_parametric(train,
                                   ds_context = context,
                                   min_instances_slice = n)
            l = log_likelihood(net, test)
            ll.append(-np.sum(l))

    print ("%6d %8.4f ± %8.4f" % (n, np.mean(ll), np.std(ll)))
# Out:
#     20 -6157.7144 ± 690.7700
#     40 -5498.0932 ± 754.2061
#     60 -4688.0358 ± 757.5470
#     80 -3678.2295 ± 460.8991
#    100 -3627.6227 ± 446.7828

# %%
from spn.io.Graphics import plot_spn
import matplotlib.pyplot as plt
# %matplotlib inline

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    context =  Context(parametric_types=ptypes).add_domains(train_data)
    net = learn_parametric(train_data, 
                           ds_context = context, 
                           min_instances_slice = 20)

plt.figure(figsize=(50, 10))
plot_spn(net)

# %%
plt.figure(figsize=(100, 25))
plot_spn(net)

# %%
from csi import annotate, context_specific_independences

annotate(net, names, categorical, min_impurity_decrease=0.1)
for rule in context_specific_independences(net):
    print (rule)
# Out:
# ([['Race == 1']], [['oDM'], ['AgeCat', 'Education', 'SmokeCat1', 'SmokeCat2'], ['BMICat'], ['Race'], ['GravCat']], 0.8609865470852018)
# ([['Race != 1']], [['AgeCat', 'BMICat', 'Race', 'Education', 'SmokeCat1', 'SmokeCat2', 'oDM'], ['GravCat']], 0.9602169981916817)
# ([['Race == 1'], ['Education > 4.5']], [['AgeCat'], ['Education'], ['SmokeCat1', 'SmokeCat2']], 0.8609865470852018)
# ([['Race != 1'], ['Race != 5']], [['AgeCat', 'Race', 'Education', 'SmokeCat1', 'SmokeCat2', 'oDM'], ['BMICat']], 0.9556876727285134)
# ([['Race == 1'], ['Education <= 4.5'], ['AgeCat > 2.5']], [['AgeCat'], ['Education', 'SmokeCat1', 'SmokeCat2']], 0.8609865470852018)
# ([['Race == 1'], ['Education <= 4.5'], ['AgeCat <= 2.5']], [['AgeCat'], ['Education', 'SmokeCat1', 'SmokeCat2']], 0.8609865470852018)
# ([['Race == 1'], ['Education > 4.5'], ['SmokeCat1 > 1.5']], [['SmokeCat1'], ['SmokeCat2']], 0.8609865470852018)
# ([['Race == 1'], ['Education > 4.5'], ['SmokeCat1 <= 1.5']], [['SmokeCat1'], ['SmokeCat2']], 0.8609865470852018)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1']], [['AgeCat', 'Education', 'oDM'], ['Race'], ['SmokeCat1', 'SmokeCat2']], 0.8762752300089521)
# ([['Race != 1'], ['Race != 5'], ['oDM == 1']], [['oDM'], ['AgeCat', 'Race', 'Education', 'SmokeCat1', 'SmokeCat2']], 0.9556876727285134)
# ([['Race != 1'], ['Race == 5'], ['Education > 4.5'], ['AgeCat <= 3.5']], [['Race'], ['SmokeCat2'], ['AgeCat', 'Education', 'oDM'], ['BMICat'], ['SmokeCat1']], 0.708970465353975)
# ([['Race != 1'], ['Race == 5'], ['Education > 4.5'], ['AgeCat > 3.5']], [['oDM'], ['AgeCat', 'BMICat', 'Race', 'SmokeCat1', 'SmokeCat2'], ['Education']], 0.5064074752528394)
# ([['Race != 1'], ['Race == 5'], ['Education <= 4.5'], ['Race == 5'], ['AgeCat <= 2.5 and BMICat <= 1.5']], [['AgeCat'], ['BMICat'], ['Race', 'Education', 'oDM'], ['SmokeCat1', 'SmokeCat2']], 0.7554403894729212)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['SmokeCat1 > 1.5']], [['SmokeCat1'], ['SmokeCat2']], 0.8762752300089521)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['SmokeCat1 <= 1.5']], [['SmokeCat1'], ['SmokeCat2']], 0.8762752300089521)
# ([['Race != 1'], ['Race == 5'], ['Education > 4.5'], ['AgeCat <= 3.5'], ['AgeCat <= 2.5']], [['AgeCat'], ['Education', 'oDM']], 0.708970465353975)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education <= 3.5'], ['AgeCat <= 2.5']], [['AgeCat'], ['Education'], ['oDM']], 0.7260566191502746)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education > 3.5'], ['Education > 4.5']], [['AgeCat'], ['Education', 'oDM']], 0.8208785200658575)
# ([['Race != 1'], ['Race != 5'], ['oDM == 1'], ['Race != 3'], ['Education <= 2.5']], [['AgeCat', 'Race', 'SmokeCat1', 'SmokeCat2'], ['Education']], 0.9556876727285134)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education <= 3.5'], ['AgeCat > 2.5'], ['AgeCat <= 3.5', 'AgeCat > 3.5 and Education > 3.5']], [['AgeCat', 'Education'], ['oDM']], 0.7260566191502746)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education > 3.5'], ['Education <= 4.5'], ['AgeCat > 1.5']], [['AgeCat'], ['Education'], ['oDM']], 0.8135492475652695)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education > 3.5'], ['Education <= 4.5'], ['AgeCat <= 1.5']], [['AgeCat'], ['Education', 'oDM']], 0.8135492475652695)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education > 3.5'], ['Education > 4.5'], ['oDM != 1']], [['Education'], ['oDM']], 0.8208785200658575)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education <= 3.5'], ['AgeCat > 2.5'], ['AgeCat <= 3.5', 'AgeCat > 3.5 and Education > 3.5'], ['Education > 3.5']], [['Education'], ['AgeCat']], 0.7260566191502746)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education <= 3.5'], ['AgeCat > 2.5'], ['AgeCat <= 3.5', 'AgeCat > 3.5 and Education > 3.5'], ['Education <= 3.5']], [['AgeCat'], ['Education']], 0.7260566191502746)
# ([['Race != 1'], ['Race != 5'], ['oDM != 1'], ['Education > 3.5'], ['Education <= 4.5'], ['AgeCat <= 1.5'], ['Education > 3.5'], ['']], [['Education'], ['oDM']], 0.8135492475652695)

# %%
net.children[0].children[1].children[1].score
# Out:
# 1.0
