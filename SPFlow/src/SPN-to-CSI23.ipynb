# %%
import numpy as np
import pandas as pd

frame = pd.read_excel("data_gdm_discrete_BMI_merged.xlsx", engine="openpyxl")
frame.oDM = (frame.oDM == 2).astype(int)
for name in frame.columns:
    frame[name] = frame[name].astype('category')

print (frame)
print (frame.oDM.value_counts())
# Out:
#      AgeCat BMICat Race Education GravCat SmokeCat1 SmokeCat2 oDM
# 0         3      0    1         3       2         1         1   0
# 1         1      2    2         2       1         1         2   0
# 2         0      0    2         1       1         2         2   0
# 3         2      2    3         3       2         2         2   0
# 4         1      0    3         4       1         2         2   0
# ...     ...    ...  ...       ...     ...       ...       ...  ..
# 9215      2      1    1         4       2         1         1   0
# 9216      1      0    3         3       2         2         2   0
# 9217      0      0    3         1       2         2         2   0
# 9218      2      1    1         2       3         1         1   0
# 9219      3      2    1         5       1         1         1   0
#
# [9220 rows x 8 columns]
# 0    8832
# 1     388
# Name: oDM, dtype: int64

# %%
from imblearn.under_sampling import NearMiss

ros = NearMiss(version = 3)
X_res, y_res = ros.fit_resample(frame.drop('oDM', axis=1), frame.oDM)
X_res['oDM'] = y_res
frame = X_res

print (frame)
# Out:
#     AgeCat BMICat Race Education GravCat SmokeCat1 SmokeCat2 oDM
# 0        2      2    6         2       3         1         1   0
# 1        2      2    6         2       3         1         1   0
# 2        0      1    6         3       1         1         1   0
# 3        2      0    5         3       3         1         1   0
# 4        0      0    5         2       1         2         2   0
# ..     ...    ...  ...       ...     ...       ...       ...  ..
# 771      1      1    1         4       1         2         2   1
# 772      3      2    1         3       2         1         2   1
# 773      2      2    1         5       1         1         2   1
# 774      4      2    1         3       1         1         2   1
# 775      2      2    3         4       1         2         2   1
#
# [776 rows x 8 columns]

# %%
from sklearn.model_selection import StratifiedKFold
from spn.algorithms.LearningWrappers import learn_parametric
from spn.structure.leaves.parametric.Parametric import Categorical, Gaussian
from spn.structure.Base import Context
import warnings 

train_data = frame.to_numpy()
names = frame.columns.tolist()
categories = ['Race', 'oDM']
ptypes = [Categorical if n in categories else Gaussian for n in names]
categorical = [n in categories for n in names]

# %%
from spn.algorithms.Inference import log_likelihood

for n in [20, 40, 60, 80, 100]:
    splitter = StratifiedKFold()
    ll = []
    for train_i, test_i in splitter.split(train_data, train_data[:, -1]):
        train = train_data[train_i]
        test = train_data[test_i]
        
        
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            context = Context(parametric_types = ptypes).add_domains(train)
            net = learn_parametric(train,
                                   ds_context = context,
                                   min_instances_slice = n)
            l = log_likelihood(net, test)
            ll.append(-np.sum(l))

    print ("%6d %8.4f ± %8.4f" % (n, np.mean(ll), np.std(ll)))
# Out:
#     20 -4490.5385 ± 512.1082
#     40 -4356.2695 ± 629.8771
#     60 -3844.6079 ± 526.3850
#     80 -3510.8288 ± 495.3449
#    100 -3498.6348 ± 508.6118

# %%
from spn.io.Graphics import plot_spn
import matplotlib.pyplot as plt
# %matplotlib inline

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    context =  Context(parametric_types=ptypes).add_domains(train_data)
    net = learn_parametric(train_data, 
                           ds_context = context, 
                           min_instances_slice = 20)

plt.figure(figsize=(50, 10))
plot_spn(net)

# %%
from csi import annotate, context_specific_independences

annotate(net, names, categorical, min_impurity_decrease=0.15)
for rule in context_specific_independences(net):
    print (rule)
# Out:
# ([['Race != 5']], [['AgeCat', 'Education'], ['BMICat'], ['Race'], ['GravCat'], ['SmokeCat1', 'SmokeCat2'], ['oDM']], 1.0)
# ([['Race == 5']], [['AgeCat', 'BMICat', 'Race', 'Education', 'SmokeCat1', 'SmokeCat2'], ['GravCat'], ['oDM']], 0.5325443786982249)
# ([['Race != 5'], ['SmokeCat1 <= 1.5']], [['SmokeCat1'], ['SmokeCat2']], 1.0)
# ([['Race != 5'], ['SmokeCat1 > 1.5']], [['SmokeCat1'], ['SmokeCat2']], 1.0)
# ([['Race == 5'], ['Education > 3.5']], [['AgeCat', 'Education'], ['BMICat'], ['Race'], ['SmokeCat1', 'SmokeCat2']], 0.5116602854159416)
# ([['Race != 5'], ['Education <= 3.5'], ['AgeCat <= 1.5']], [['AgeCat'], ['Education']], 0.960431654676259)
# ([['Race == 5'], ['Education <= 3.5'], ['Race == 8']], [['AgeCat', 'BMICat', 'Education', 'SmokeCat1', 'SmokeCat2'], ['Race']], 0.4443891355487223)
# ([['Race != 5'], ['Education > 3.5'], ['Education <= 4.5'], ['AgeCat > 3.5']], [['AgeCat'], ['Education']], 0.8936170212765957)
# ([['Race != 5'], ['Education > 3.5'], ['Education <= 4.5'], ['AgeCat <= 3.5']], [['Education'], ['AgeCat']], 0.8936170212765957)
# ([['Race != 5'], ['Education > 3.5'], ['Education > 4.5'], ['AgeCat > 2.5']], [['AgeCat'], ['Education']], 0.8936170212765957)
# ([['Race != 5'], ['Education <= 3.5'], ['AgeCat > 1.5'], ['AgeCat <= 2.5']], [['AgeCat'], ['Education']], 0.960431654676259)
# ([['Race == 5'], ['Education > 3.5'], ['AgeCat > 3.5']], [['AgeCat'], ['Education']], 0.4697209177588972)
# ([['Race == 5'], ['Education > 3.5'], ['SmokeCat1 <= 1.5']], [['SmokeCat1'], ['SmokeCat2']], 0.5116602854159416)
# ([['Race == 5'], ['Education > 3.5'], ['SmokeCat1 > 1.5']], [['SmokeCat1'], ['SmokeCat2']], 0.5116602854159416)
# ([['Race != 5'], ['Education > 3.5'], ['Education > 4.5'], ['AgeCat <= 2.5'], ['Education <= 5.5']], [['Education'], ['AgeCat']], 0.8936170212765957)
# ([['Race != 5'], ['Education <= 3.5'], ['AgeCat > 1.5'], ['AgeCat > 2.5'], ['AgeCat <= 3.5']], [['AgeCat'], ['Education']], 0.960431654676259)

# %%
net.children[0].children[1].children[1].score
# Out:
# 1.0
